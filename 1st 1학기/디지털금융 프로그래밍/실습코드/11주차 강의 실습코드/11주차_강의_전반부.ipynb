# %% [markdown]
# # Assets

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt

# %%
df = data.DataReader(['AAPL', 'NKE', 'GOOGL', 'AMZN', 'FB'], 'yahoo', start='2018/01/01', end='2022/04/30')
df
# Out:
# Attributes   Adj Close                                                    \
# Symbols           AAPL         NKE        GOOGL         AMZN          FB
# Date
# 2018-01-02   41.075409   60.938107  1073.209961  1189.010010  181.419998
# 2018-01-03   41.068249   60.928505  1091.520020  1204.199951  184.669998
# 2018-01-04   41.259003   60.890118  1095.760010  1209.589966  184.330002
# 2018-01-05   41.728756   61.408413  1110.290039  1229.140015  186.850006
# 2018-01-08   41.573776   61.955505  1114.209961  1246.869995  188.279999
# ...                ...         ...          ...          ...         ...
# 2022-04-25  162.641037  127.940002  2461.479980  2921.479980  186.990005
# 2022-04-26  156.569962  120.519997  2373.000000  2787.820068  180.949997
# 2022-04-27  156.340302  121.239998  2285.889893  2763.340088  174.949997
# 2022-04-28  163.399918  127.050003  2370.449951  2891.929932  205.729996
# 2022-04-29  157.418701  124.699997  2282.189941  2485.629883  200.470001
#
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2022-04-18', '2022-04-19', '2022-04-20', '2022-04-21',
#                '2022-04-22', '2022-04-25', '2022-04-26', '2022-04-27',
#                '2022-04-28', '2022-04-29'],
#               dtype='datetime64[ns]', name='Date', length=1090, freq=None)

# %%
df.columns
# Out:
# MultiIndex([('Adj Close',  'AAPL'),
#             ('Adj Close',   'NKE'),
#             ('Adj Close', 'GOOGL'),
#             ('Adj Close',  'AMZN'),
#             ('Adj Close',    'FB'),
#             (    'Close',  'AAPL'),
#             (    'Close',   'NKE'),
#             (    'Close', 'GOOGL'),
#             (    'Close',  'AMZN'),
#             (    'Close',    'FB'),
#             (     'High',  'AAPL'),
#             (     'High',   'NKE'),
#             (     'High', 'GOOGL'),
#             (     'High',  'AMZN'),
#             (     'High',    'FB'),
#             (      'Low',  'AAPL'),
#             (      'Low',   'NKE'),
#             (      'Low', 'GOOGL'),
#             (      'Low',  'AMZN'),
#             (      'Low',    'FB'),
#             (     'Open',  'AAPL'),
#             (     'Open',   'NKE'),
#             (     'Open', 'GOOGL'),
#             (     'Open',  'AMZN'),
#             (     'Open',    'FB'),
#             (   'Volume',  'AAPL'),
# ...

# %%
df = df['Adj Close'] #수정주가

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-16',
#                ...
#                '2022-04-18', '2022-04-19', '2022-04-20', '2022-04-21',
#                '2022-04-22', '2022-04-25', '2022-04-26', '2022-04-27',
#                '2022-04-28', '2022-04-29'],
#               dtype='datetime64[ns]', name='Date', length=1090, freq=None)

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(df / df.iloc[0] * 100).plot() #5개 종목에 수익률 추이를 볼 수 있음
# Out:
# <AxesSubplot:xlabel='Date'>
